# %% [markdown]
# # Experiment 1, part a for DBLP data

# %%
import json
import numpy as np

with open('../data/exp1-a_dblp.json') as exp1a_file:
    freq_errors = json.load(exp1a_file)

import matplotlib.pyplot as plt

y = np.array(freq_errors)
x = np.array([1/160, 1/140, 1/120, 1/100, 1/80, 1/60, 1/40])

fig,ax = plt.subplots(1)
plt.title('DBLP')
plt.ylabel('Average relative error')
plt.xlabel('Compression ratio')
ax.plot(x,y)
